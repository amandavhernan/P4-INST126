# %%
import numpy as np
import pandas as pd
#import os
from matplotlib import pyplot as plt
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
import seaborn as sns

# %%
admitList = pd.read_csv('UMD.csv', index_col=0)

# %%
admitList = admitList.loc[:, ~admitList.columns.str.contains('^Unnamed')]
admitList.head()
# Out:
#            GPA (Weighted)  SAT
# Admission
# No                   2.62  750
# No                   2.57  770
# No                   2.89  820
# No                   3.63  910
# No                   3.11  910

# %%
admitList.count()
# Out:
# GPA (Weighted)    332
# SAT               332
# dtype: int64

# %%
admitList.columns
# Out:
# Index(['GPA (Weighted)', 'SAT'], dtype='object')

# %%
admitList.head(50)
# Out:
#            GPA (Weighted)   SAT
# Admission
# No                   2.62   750
# No                   2.57   770
# No                   2.89   820
# No                   3.63   910
# No                   3.11   910
# No                   2.74   930
# No                   2.89   950
# No                   3.19   950
# No                   2.64   980
# No                   2.86   990
# No                   3.34   980
# No                   3.84  1000
# No                   3.54  1010
# No                   2.93  1010
# No                   2.68  1020
# No                   2.23  1030
# No                   2.67  1030
# No                   2.90  1030
# No                   2.98  1030
# No                   3.03  1030
# No                   3.12  1030
# Yes                  3.15  1030
# No                   3.33  1030
# No                   3.38  1030
# No                   3.00  1040
# Yes                  4.41  1020
# Yes                  3.80  1040
# No                   3.85  1040
# ...

# %%
admitList.describe()
admitList.dropna(axis='columns')
# Out:
#            GPA (Weighted)   SAT
# Admission
# No                   2.62   750
# No                   2.57   770
# No                   2.89   820
# No                   3.63   910
# No                   3.11   910
# ...                   ...   ...
# Yes                  4.84  1560
# Yes                  4.66  1570
# Yes                  4.65  1570
# Yes                  4.58  1580
# Yes                  4.50  1600
#
# [332 rows x 2 columns]

# %%
fig, ax = plt.subplots(figsize=(10,5))
sns.heatmap(admitList.corr(), annot=True, cmap='inferno')

# %%
fig, ax = plt.subplots((1), figsize=(8,8))
plt.scatter(admitList['GPA (Weighted)'], admitList['SAT'])
plt.xlabel('GPA (Weighted)')
plt.ylabel('SAT')
ax.title.set_text('SAT scores & GPA of UMD applicants')
plt.show()

# %%
#train
#x = admitList.iloc[:]
#y = admitList.iloc[:]

# %%
#x_train, x_test, y_train, y_test = train_test_split(x, y,)

# %%
# Implement random forest regressor
# rf = RandomForestRegressor

# %%
#rf.fit(x_train, y_train)

# %%
# input an gpa, sat score
# newApplicant = [[3.5, 1040]]

# %%
# supposed to run a prediction based off gpa and sat score, gives % chance of admission
pred = rf.predict(newApplicant)
pred[0]
